# %%
from preprocessing import load_blockwise_sequences, load_labels_and_subjects, stratified_group_split, \
    oversample_minority_classes, print_class_distribution, smote_expand_dataset, normalize_axes_separately
from helper import LSTMModel, CNN1DModel, TransformerModel, train_model, test_model
from torch.utils.data import TensorDataset, DataLoader
import torch
from itertools import product


def run_experiment(
        batch_size=64,
        learning_rate=0.001,
        hidden_layers=[250, 250, 50],
        conv_config=None,
        dropout_rate=0.4,
        epochs=200,
        patience=20,
        model_type='lstm',
):
    # load and split data
    X = load_blockwise_sequences("fall_data_split_blocks.csv")
    labels, subject_ids = load_labels_and_subjects("fall_labels.csv")
    X_train, X_test, y_train, y_test = stratified_group_split(X, labels, subject_ids)

    #print(f"Loaded data: {X.shape}")
    #print(f"Min label: {labels.min().item()}, Max label: {labels.max().item()}")

    # oversample training data
    X_train_tensor = torch.stack([X[i] for i in X_train.indices])
    y_train_tensor = y_train
    X_balanced, y_balanced = oversample_minority_classes(X_train_tensor, y_train_tensor)

    # sanity check: shuffle labels to test for data leakage or broken signal
    if model_type.endswith("_shuffled"):
        model_type = model_type.split('_')[0]
        print("Shuffling training labels for sanity check")
        idx = torch.randperm(len(y_balanced))
        y_balanced = y_balanced[idx]

    # extract raw test tensor
    # X_test_tensor = torch.stack([X[i] for i in X_test.indices])

    # expand dataset with SMOTE to ~5000 samples per class
    # X_balanced, y_balanced = smote_expand_dataset(X_balanced, y_balanced, target_per_class=5000)

    # normalize each axis using train stats
    # X_balanced, X_test_tensor = normalize_axes_separately(X_balanced, X_test_tensor)

    #print_class_distribution(y_balanced, "Train")
    #print_class_distribution(y_test, "Test")

    # train and validation datasets/loaders
    train_dataset = TensorDataset(X_balanced, y_balanced)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    val_dataset = TensorDataset(torch.stack([X[i] for i in X_test.indices]), y_test)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # model and training setup
    if model_type == 'lstm':
        model = LSTMModel(hidden_layers=hidden_layers, dropout_rate=dropout_rate, out_features=8)
    elif model_type == 'cnn':
        model = CNN1DModel(
            conv_config=conv_config,
            hidden_layers=hidden_layers,
            dropout_rate=dropout_rate,
            input_length=151,
            input_channels=3,
            out_features=8,
            pool_every=3
        )
    elif model_type == 'transformer':
        model = TransformerModel(hidden_layers=hidden_layers, dropout_rate=dropout_rate)
    else:
        raise ValueError(f"Unsupported model_type: {model_type}")

    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    criterion = torch.nn.CrossEntropyLoss()
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    print(f"Using device: {device}")
    print(f"Model: {model_type.upper()}, Layers: {hidden_layers}, Dropout: {dropout_rate}, LR: {learning_rate}")

    # train and get final validation accuracy
    train_model(model, train_loader, val_loader, optimizer, criterion, device, epochs=epochs, patience=patience)
    final_acc = test_model(model, val_loader, device, print_output=True)
    print(f"Final Validation Accuracy: {final_acc:.4f}")


def run_hyperparameter_search():
    # define hyperparameter options
    batch_sizes = [64, 100]
    learning_rates = [.0002,]
    hidden_layer_options = [[64], [64], [64]]
    dropout_rates = [.85,]
    model_types = ['cnn']
    epochs = 200
    patience = 15

    conv_config_options = [
        #[(64, 12), (128, 12), (256, 12), (256, 12)],
        #[(64, 10), (128, 10), (256, 10), (512, 10)],
        #[(128, 10), (256, 10), (512, 10), (1024, 10)],
        #[(64, 10), (128, 10), (256, 10), (512, 10), (512, 10)],
        #[(12, 10), (128, 10), (256, 10), (512, 10), (1024, 10)], # best so far (w/ 0.7 dropout)
        #[(12, 10), (128, 10), (256, 10), (512, 10), (1024, 10), (2048, 10)], # best so far (w/ 0.8 dropout)
        # [(8, 10), (32, 10), (64, 10), (128, 10), (512, 10), (1024, 10)], # best so far (w/ 0.8 dropout) !!!!
        [(8, 10), (32, 10), (128, 10), (512, 10), (128, 10)],  # (actually best so far 0.55)
        #[(8, 10), (32, 10), (128, 10), (32, 10)],
        #[(256, 10), (512, 10), (128, 10), (32, 10)],
        #[(8, 10), (256, 10), (512, 10), (128, 10)],
        #[(8, 10), (64, 10), (256, 10), (64, 10), (128, 10)],
        #[(512, 10), (128, 10), (64, 10), (32, 10)],
        #[(12, 10), (128, 10), (256, 10), (512, 10), (2048, 10)],
        # [(64, 8), (128, 8), (256, 8), (256, 8)],
        # [(64, 6), (128, 6), (256, 6), (256, 6)],
        # [(64, 4), (128, 4), (256, 4), (256, 4)],
    ]

    # create all combinations including model_type
    combinations = list(product(
        batch_sizes,
        learning_rates,
        hidden_layer_options,
        conv_config_options,
        dropout_rates,
        model_types
    ))

    for i, (batch_size, lr, hidden_layers, conv_config, dropout, model_type) in enumerate(combinations):
        print(f"\nRunning configuration {i + 1}/{len(combinations)}")
        print(
            f"Model: {model_type.upper()}, Batch Size: {batch_size}, LR: {lr}, Conv: {conv_config}, Layers: {hidden_layers}, Dropout: {dropout}")

        run_experiment(
            batch_size=batch_size,
            learning_rate=lr,
            hidden_layers=hidden_layers,
            conv_config=conv_config,
            dropout_rate=dropout,
            epochs=epochs,
            patience=patience,
            model_type=model_type
        )


run_hyperparameter_search()
# Out:
# Running configuration 1/6
# Model: CNN, Batch Size: 64, LR: 0.0002, Conv: [(8, 10), (32, 10), (128, 10), (512, 10), (128, 10)], Layers: [64], Dropout: 0.85
# ____________________update_3___________________________
# Using device: cuda
# Model: CNN, Layers: [64], Dropout: 0.85, LR: 0.0002
# pushed 1:44ipup
# Epoch 1 | Train Loss: 2.0370 | Train Acc: 0.2951 | Val Acc: 0.2138
# Epoch 2 | Train Loss: 1.9727 | Train Acc: 0.3441 | Val Acc: 0.2407
# Epoch 3 | Train Loss: 1.9297 | Train Acc: 0.3770 | Val Acc: 0.2676
# Epoch 4 | Train Loss: 1.8684 | Train Acc: 0.4050 | Val Acc: 0.2661
# Epoch 5 | Train Loss: 1.8176 | Train Acc: 0.3968 | Val Acc: 0.1973
# Epoch 6 | Train Loss: 1.7619 | Train Acc: 0.5169 | Val Acc: 0.2586
# Epoch 7 | Train Loss: 1.6790 | Train Acc: 0.5457 | Val Acc: 0.2975
# Epoch 8 | Train Loss: 1.5961 | Train Acc: 0.5941 | Val Acc: 0.3378
# Epoch 9 | Train Loss: 1.5241 | Train Acc: 0.6070 | Val Acc: 0.3184
# Epoch 10 | Train Loss: 1.4732 | Train Acc: 0.6543 | Val Acc: 0.3438
# Epoch 11 | Train Loss: 1.4020 | Train Acc: 0.6836 | Val Acc: 0.3647
# Epoch 12 | Train Loss: 1.3569 | Train Acc: 0.7413 | Val Acc: 0.3901
# Epoch 13 | Train Loss: 1.3138 | Train Acc: 0.7573 | Val Acc: 0.3961
# Epoch 14 | Train Loss: 1.2691 | Train Acc: 0.7844 | Val Acc: 0.4066
# Epoch 15 | Train Loss: 1.1951 | Train Acc: 0.7988 | Val Acc: 0.3871
# Epoch 16 | Train Loss: 1.1636 | Train Acc: 0.8075 | Val Acc: 0.4081
# Epoch 17 | Train Loss: 1.1004 | Train Acc: 0.8302 | Val Acc: 0.3976
# Epoch 18 | Train Loss: 1.0563 | Train Acc: 0.8688 | Val Acc: 0.4126
# Epoch 19 | Train Loss: 1.0185 | Train Acc: 0.8717 | Val Acc: 0.4260
# Epoch 20 | Train Loss: 0.9843 | Train Acc: 0.8792 | Val Acc: 0.4185
# Epoch 21 | Train Loss: 0.9533 | Train Acc: 0.8939 | Val Acc: 0.4305
# Epoch 22 | Train Loss: 0.9189 | Train Acc: 0.9127 | Val Acc: 0.4126
# Epoch 23 | Train Loss: 0.8675 | Train Acc: 0.8728 | Val Acc: 0.3961
# Epoch 24 | Train Loss: 0.8785 | Train Acc: 0.8921 | Val Acc: 0.4096
# Epoch 25 | Train Loss: 0.8107 | Train Acc: 0.9241 | Val Acc: 0.4380
# Epoch 26 | Train Loss: 0.8075 | Train Acc: 0.9303 | Val Acc: 0.4245
# Epoch 27 | Train Loss: 0.7620 | Train Acc: 0.9305 | Val Acc: 0.4395
# Epoch 28 | Train Loss: 0.7294 | Train Acc: 0.9329 | Val Acc: 0.4290
# Epoch 29 | Train Loss: 0.7331 | Train Acc: 0.9529 | Val Acc: 0.4036
# Epoch 30 | Train Loss: 0.7089 | Train Acc: 0.9591 | Val Acc: 0.4200
# Epoch 31 | Train Loss: 0.7009 | Train Acc: 0.9647 | Val Acc: 0.4753
# Epoch 32 | Train Loss: 0.6951 | Train Acc: 0.9589 | Val Acc: 0.4141
# Epoch 33 | Train Loss: 0.6441 | Train Acc: 0.9742 | Val Acc: 0.4051
# Epoch 34 | Train Loss: 0.6132 | Train Acc: 0.9751 | Val Acc: 0.4514
# Epoch 35 | Train Loss: 0.6329 | Train Acc: 0.9762 | Val Acc: 0.4126
# Epoch 36 | Train Loss: 0.6344 | Train Acc: 0.9745 | Val Acc: 0.4170
# Epoch 37 | Train Loss: 0.5965 | Train Acc: 0.9820 | Val Acc: 0.4529
# Epoch 38 | Train Loss: 0.5818 | Train Acc: 0.9876 | Val Acc: 0.4335
# Epoch 39 | Train Loss: 0.6199 | Train Acc: 0.9867 | Val Acc: 0.4335
# Epoch 40 | Train Loss: 0.5882 | Train Acc: 0.9751 | Val Acc: 0.4066
# Epoch 41 | Train Loss: 0.5644 | Train Acc: 0.9909 | Val Acc: 0.4335
# Epoch 42 | Train Loss: 0.5470 | Train Acc: 0.9860 | Val Acc: 0.4574
# Epoch 43 | Train Loss: 0.5261 | Train Acc: 0.9891 | Val Acc: 0.4305
# Epoch 44 | Train Loss: 0.5430 | Train Acc: 0.9871 | Val Acc: 0.4380
# Epoch 45 | Train Loss: 0.5230 | Train Acc: 0.9882 | Val Acc: 0.4619
# Epoch 46 | Train Loss: 0.5205 | Train Acc: 0.9964 | Val Acc: 0.4709
# Early stopping triggered after 46 epochs. Best Val Acc: 0.4753
# Balanced Accuracy: 0.4671
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.47      0.51        87
#            1       0.40      0.56      0.47        72
#            2       0.44      0.35      0.39       103
#            3       0.53      0.77      0.62        98
#            4       0.42      0.43      0.43        67
#            5       0.52      0.40      0.45        80
#            6       0.40      0.40      0.40        87
#            7       0.52      0.36      0.43        75
#
#     accuracy                           0.47       669
#    macro avg       0.47      0.47      0.46       669
# weighted avg       0.47      0.47      0.46       669
# Final Validation Accuracy: 0.4709
#
# Running configuration 2/6
# Model: CNN, Batch Size: 64, LR: 0.0002, Conv: [(8, 10), (32, 10), (128, 10), (512, 10), (128, 10)], Layers: [64], Dropout: 0.85
# ____________________update_3___________________________
# Using device: cuda
# Model: CNN, Layers: [64], Dropout: 0.85, LR: 0.0002
# pushed 1:44ipup
# Epoch 1 | Train Loss: 2.0618 | Train Acc: 0.2420 | Val Acc: 0.1898
# Epoch 2 | Train Loss: 2.0167 | Train Acc: 0.3048 | Val Acc: 0.2526
# Epoch 3 | Train Loss: 1.9661 | Train Acc: 0.3306 | Val Acc: 0.2541
# Epoch 4 | Train Loss: 1.9303 | Train Acc: 0.3641 | Val Acc: 0.2990
# Epoch 5 | Train Loss: 1.8836 | Train Acc: 0.4212 | Val Acc: 0.2915
# Epoch 6 | Train Loss: 1.8636 | Train Acc: 0.4505 | Val Acc: 0.3288
# Epoch 7 | Train Loss: 1.7797 | Train Acc: 0.4829 | Val Acc: 0.3274
# Epoch 8 | Train Loss: 1.7083 | Train Acc: 0.5369 | Val Acc: 0.3408
# Epoch 9 | Train Loss: 1.6199 | Train Acc: 0.5688 | Val Acc: 0.3184
# Epoch 10 | Train Loss: 1.5775 | Train Acc: 0.6152 | Val Acc: 0.3333
# Epoch 11 | Train Loss: 1.5361 | Train Acc: 0.6159 | Val Acc: 0.3154
# Epoch 12 | Train Loss: 1.4848 | Train Acc: 0.6292 | Val Acc: 0.3288
# Epoch 13 | Train Loss: 1.4020 | Train Acc: 0.6865 | Val Acc: 0.3378
# Epoch 14 | Train Loss: 1.3543 | Train Acc: 0.6561 | Val Acc: 0.3094
# Epoch 15 | Train Loss: 1.3156 | Train Acc: 0.7349 | Val Acc: 0.3154
# Epoch 16 | Train Loss: 1.2982 | Train Acc: 0.7278 | Val Acc: 0.3363
# Epoch 17 | Train Loss: 1.2809 | Train Acc: 0.7740 | Val Acc: 0.3363
# Epoch 18 | Train Loss: 1.2183 | Train Acc: 0.7662 | Val Acc: 0.3827
# Epoch 19 | Train Loss: 1.1708 | Train Acc: 0.7924 | Val Acc: 0.3812
# Epoch 20 | Train Loss: 1.1399 | Train Acc: 0.8184 | Val Acc: 0.3692
# Epoch 21 | Train Loss: 1.1243 | Train Acc: 0.8321 | Val Acc: 0.3647
# Epoch 22 | Train Loss: 1.0766 | Train Acc: 0.8548 | Val Acc: 0.3767
# Epoch 23 | Train Loss: 1.0322 | Train Acc: 0.8672 | Val Acc: 0.3303
# Epoch 24 | Train Loss: 1.0357 | Train Acc: 0.8561 | Val Acc: 0.3647
# Epoch 25 | Train Loss: 0.9982 | Train Acc: 0.8732 | Val Acc: 0.3468
# Epoch 26 | Train Loss: 0.9551 | Train Acc: 0.9132 | Val Acc: 0.3842
# Epoch 27 | Train Loss: 0.9501 | Train Acc: 0.8941 | Val Acc: 0.3617
# Epoch 28 | Train Loss: 0.9202 | Train Acc: 0.9090 | Val Acc: 0.3722
# Epoch 29 | Train Loss: 0.9040 | Train Acc: 0.9298 | Val Acc: 0.3752
# Epoch 30 | Train Loss: 0.8842 | Train Acc: 0.9416 | Val Acc: 0.4275
# Epoch 31 | Train Loss: 0.8499 | Train Acc: 0.9261 | Val Acc: 0.3976
# Epoch 32 | Train Loss: 0.8347 | Train Acc: 0.9458 | Val Acc: 0.3916
# Epoch 33 | Train Loss: 0.8344 | Train Acc: 0.9605 | Val Acc: 0.3901
# Epoch 34 | Train Loss: 0.8225 | Train Acc: 0.9563 | Val Acc: 0.3498
# Epoch 35 | Train Loss: 0.8152 | Train Acc: 0.9571 | Val Acc: 0.3842
# Epoch 36 | Train Loss: 0.7937 | Train Acc: 0.9500 | Val Acc: 0.3767
# Epoch 37 | Train Loss: 0.7815 | Train Acc: 0.9780 | Val Acc: 0.3797
# Epoch 38 | Train Loss: 0.7900 | Train Acc: 0.9731 | Val Acc: 0.3692
# Epoch 39 | Train Loss: 0.7302 | Train Acc: 0.9818 | Val Acc: 0.3976
# Epoch 40 | Train Loss: 0.7135 | Train Acc: 0.9860 | Val Acc: 0.3692
# Epoch 41 | Train Loss: 0.7079 | Train Acc: 0.9836 | Val Acc: 0.4155
# Epoch 42 | Train Loss: 0.7149 | Train Acc: 0.9809 | Val Acc: 0.3946
# Epoch 43 | Train Loss: 0.6942 | Train Acc: 0.9891 | Val Acc: 0.4036
# Epoch 44 | Train Loss: 0.7136 | Train Acc: 0.9936 | Val Acc: 0.3827
# Epoch 45 | Train Loss: 0.6881 | Train Acc: 0.9845 | Val Acc: 0.3692
# Early stopping triggered after 45 epochs. Best Val Acc: 0.4275
# Balanced Accuracy: 0.3747
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.23      0.29        87
#            1       0.30      0.50      0.37        72
#            2       0.34      0.39      0.36       103
#            3       0.75      0.41      0.53        98
#            4       0.45      0.51      0.48        67
#            5       0.62      0.36      0.46        80
#            6       0.14      0.24      0.18        87
#            7       0.47      0.36      0.41        75
#
#     accuracy                           0.37       669
#    macro avg       0.43      0.37      0.38       669
# weighted avg       0.44      0.37      0.38       669
# Final Validation Accuracy: 0.3692
#
# Running configuration 3/6
# Model: CNN, Batch Size: 64, LR: 0.0002, Conv: [(8, 10), (32, 10), (128, 10), (512, 10), (128, 10)], Layers: [64], Dropout: 0.85
# ____________________update_3___________________________
# Using device: cuda
# Model: CNN, Layers: [64], Dropout: 0.85, LR: 0.0002
# pushed 1:44ipup
# Epoch 1 | Train Loss: 2.0586 | Train Acc: 0.2240 | Val Acc: 0.1540
# Epoch 2 | Train Loss: 2.0012 | Train Acc: 0.2706 | Val Acc: 0.1689
# Epoch 3 | Train Loss: 1.9324 | Train Acc: 0.3890 | Val Acc: 0.2945
# Epoch 4 | Train Loss: 1.8656 | Train Acc: 0.4072 | Val Acc: 0.2586
# Epoch 5 | Train Loss: 1.7987 | Train Acc: 0.4634 | Val Acc: 0.2541
# Epoch 6 | Train Loss: 1.7583 | Train Acc: 0.4378 | Val Acc: 0.2840
# Epoch 7 | Train Loss: 1.7357 | Train Acc: 0.4880 | Val Acc: 0.2586
# Epoch 8 | Train Loss: 1.6832 | Train Acc: 0.5422 | Val Acc: 0.2855
# Epoch 9 | Train Loss: 1.6387 | Train Acc: 0.5593 | Val Acc: 0.3229
# Epoch 10 | Train Loss: 1.5742 | Train Acc: 0.5950 | Val Acc: 0.3244
# Epoch 11 | Train Loss: 1.5139 | Train Acc: 0.6312 | Val Acc: 0.3528
# Epoch 12 | Train Loss: 1.4692 | Train Acc: 0.6718 | Val Acc: 0.3528
# Epoch 13 | Train Loss: 1.4034 | Train Acc: 0.6632 | Val Acc: 0.3662
# Epoch 14 | Train Loss: 1.3913 | Train Acc: 0.7198 | Val Acc: 0.3423
# Epoch 15 | Train Loss: 1.3237 | Train Acc: 0.7611 | Val Acc: 0.3752
# Epoch 16 | Train Loss: 1.2968 | Train Acc: 0.7675 | Val Acc: 0.3662
# Epoch 17 | Train Loss: 1.2204 | Train Acc: 0.7749 | Val Acc: 0.3199
# Epoch 18 | Train Loss: 1.1851 | Train Acc: 0.8213 | Val Acc: 0.3886
# Epoch 19 | Train Loss: 1.1728 | Train Acc: 0.8111 | Val Acc: 0.3483
# Epoch 20 | Train Loss: 1.1251 | Train Acc: 0.8430 | Val Acc: 0.3797
# Epoch 21 | Train Loss: 1.0977 | Train Acc: 0.8537 | Val Acc: 0.4081
# Epoch 22 | Train Loss: 1.0576 | Train Acc: 0.8581 | Val Acc: 0.3916
# Epoch 23 | Train Loss: 1.0315 | Train Acc: 0.8983 | Val Acc: 0.3647
# Epoch 24 | Train Loss: 0.9894 | Train Acc: 0.8726 | Val Acc: 0.4155
# Epoch 25 | Train Loss: 0.9680 | Train Acc: 0.8925 | Val Acc: 0.3916
# Epoch 26 | Train Loss: 0.9222 | Train Acc: 0.9136 | Val Acc: 0.4170
# Epoch 27 | Train Loss: 0.8679 | Train Acc: 0.9238 | Val Acc: 0.4066
# Epoch 28 | Train Loss: 0.8613 | Train Acc: 0.9263 | Val Acc: 0.4469
# Epoch 29 | Train Loss: 0.8452 | Train Acc: 0.9327 | Val Acc: 0.4380
# Epoch 30 | Train Loss: 0.8333 | Train Acc: 0.9454 | Val Acc: 0.4305
# Epoch 31 | Train Loss: 0.8109 | Train Acc: 0.9467 | Val Acc: 0.4170
# Epoch 32 | Train Loss: 0.7545 | Train Acc: 0.9596 | Val Acc: 0.4185
# Epoch 33 | Train Loss: 0.7573 | Train Acc: 0.9532 | Val Acc: 0.4230
# Epoch 34 | Train Loss: 0.7173 | Train Acc: 0.9638 | Val Acc: 0.3946
# Epoch 35 | Train Loss: 0.6902 | Train Acc: 0.9685 | Val Acc: 0.4484
# Epoch 36 | Train Loss: 0.6898 | Train Acc: 0.9707 | Val Acc: 0.4051
# Epoch 37 | Train Loss: 0.6673 | Train Acc: 0.9771 | Val Acc: 0.4170
# Epoch 38 | Train Loss: 0.6536 | Train Acc: 0.9789 | Val Acc: 0.4096
# Epoch 39 | Train Loss: 0.6336 | Train Acc: 0.9725 | Val Acc: 0.3946
# Epoch 40 | Train Loss: 0.6787 | Train Acc: 0.9683 | Val Acc: 0.4305
# Epoch 41 | Train Loss: 0.6165 | Train Acc: 0.9818 | Val Acc: 0.4200
# Epoch 42 | Train Loss: 0.6001 | Train Acc: 0.9833 | Val Acc: 0.4200
# Epoch 43 | Train Loss: 0.5442 | Train Acc: 0.9880 | Val Acc: 0.4320
# Epoch 44 | Train Loss: 0.5681 | Train Acc: 0.9851 | Val Acc: 0.4215
# Epoch 45 | Train Loss: 0.5417 | Train Acc: 0.9858 | Val Acc: 0.4469
# Epoch 46 | Train Loss: 0.5295 | Train Acc: 0.9845 | Val Acc: 0.4260
# Epoch 47 | Train Loss: 0.5485 | Train Acc: 0.9902 | Val Acc: 0.4260
# Epoch 48 | Train Loss: 0.5164 | Train Acc: 0.9936 | Val Acc: 0.4454
# Epoch 49 | Train Loss: 0.5088 | Train Acc: 0.9887 | Val Acc: 0.4484
# Epoch 50 | Train Loss: 0.5056 | Train Acc: 0.9918 | Val Acc: 0.4290
# Early stopping triggered after 50 epochs. Best Val Acc: 0.4484
# Balanced Accuracy: 0.4404
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.49      0.51        87
#            1       0.37      0.58      0.45        72
#            2       0.32      0.23      0.27       103
#            3       0.66      0.43      0.52        98
#            4       0.53      0.58      0.56        67
#            5       0.47      0.35      0.40        80
#            6       0.26      0.43      0.33        87
#            7       0.49      0.43      0.46        75
#
#     accuracy                           0.43       669
#    macro avg       0.46      0.44      0.44       669
# weighted avg       0.46      0.43      0.43       669
# Final Validation Accuracy: 0.4290
#
# Running configuration 4/6
# Model: CNN, Batch Size: 100, LR: 0.0002, Conv: [(8, 10), (32, 10), (128, 10), (512, 10), (128, 10)], Layers: [64], Dropout: 0.85
# ____________________update_3___________________________
# Using device: cuda
# Model: CNN, Layers: [64], Dropout: 0.85, LR: 0.0002
# pushed 1:44ipup
# Epoch 1 | Train Loss: 2.0610 | Train Acc: 0.2702 | Val Acc: 0.1854
# Epoch 2 | Train Loss: 1.9974 | Train Acc: 0.3512 | Val Acc: 0.2033
# Epoch 3 | Train Loss: 1.9383 | Train Acc: 0.3794 | Val Acc: 0.1854
# Epoch 4 | Train Loss: 1.9042 | Train Acc: 0.4230 | Val Acc: 0.2093
# Epoch 5 | Train Loss: 1.8686 | Train Acc: 0.4454 | Val Acc: 0.2123
# Epoch 6 | Train Loss: 1.8248 | Train Acc: 0.4638 | Val Acc: 0.2287
# Epoch 7 | Train Loss: 1.7927 | Train Acc: 0.4665 | Val Acc: 0.2063
# Epoch 8 | Train Loss: 1.7407 | Train Acc: 0.4860 | Val Acc: 0.2182
# Epoch 9 | Train Loss: 1.7167 | Train Acc: 0.5189 | Val Acc: 0.2167
# Epoch 10 | Train Loss: 1.6419 | Train Acc: 0.5868 | Val Acc: 0.2466
# Epoch 11 | Train Loss: 1.6193 | Train Acc: 0.6015 | Val Acc: 0.2915
# Epoch 12 | Train Loss: 1.5646 | Train Acc: 0.6448 | Val Acc: 0.2272
# Epoch 13 | Train Loss: 1.5263 | Train Acc: 0.6368 | Val Acc: 0.2586
# Epoch 14 | Train Loss: 1.5073 | Train Acc: 0.6912 | Val Acc: 0.2601
# Epoch 15 | Train Loss: 1.4179 | Train Acc: 0.6896 | Val Acc: 0.2870
# Epoch 16 | Train Loss: 1.3824 | Train Acc: 0.7407 | Val Acc: 0.3244
# Epoch 17 | Train Loss: 1.3390 | Train Acc: 0.7358 | Val Acc: 0.3408
# Epoch 18 | Train Loss: 1.2795 | Train Acc: 0.7347 | Val Acc: 0.3154
# Epoch 19 | Train Loss: 1.2725 | Train Acc: 0.7829 | Val Acc: 0.3617
# Epoch 20 | Train Loss: 1.2172 | Train Acc: 0.8013 | Val Acc: 0.3827
# Epoch 21 | Train Loss: 1.1596 | Train Acc: 0.8111 | Val Acc: 0.3737
# Epoch 22 | Train Loss: 1.2074 | Train Acc: 0.8106 | Val Acc: 0.3812
# Epoch 23 | Train Loss: 1.1103 | Train Acc: 0.8437 | Val Acc: 0.3901
# Epoch 24 | Train Loss: 1.0689 | Train Acc: 0.8457 | Val Acc: 0.4155
# Epoch 25 | Train Loss: 1.0349 | Train Acc: 0.8577 | Val Acc: 0.3991
# Epoch 26 | Train Loss: 0.9957 | Train Acc: 0.8852 | Val Acc: 0.4200
# Epoch 27 | Train Loss: 0.9970 | Train Acc: 0.8799 | Val Acc: 0.3916
# Epoch 28 | Train Loss: 0.9577 | Train Acc: 0.8768 | Val Acc: 0.4290
# Epoch 29 | Train Loss: 0.9693 | Train Acc: 0.8857 | Val Acc: 0.4081
# Epoch 30 | Train Loss: 0.8961 | Train Acc: 0.9074 | Val Acc: 0.4051
# Epoch 31 | Train Loss: 0.8856 | Train Acc: 0.9201 | Val Acc: 0.4335
# Epoch 32 | Train Loss: 0.8414 | Train Acc: 0.9203 | Val Acc: 0.4425
# Epoch 33 | Train Loss: 0.8659 | Train Acc: 0.9263 | Val Acc: 0.3961
# Epoch 34 | Train Loss: 0.8405 | Train Acc: 0.9207 | Val Acc: 0.4664
# Epoch 35 | Train Loss: 0.8395 | Train Acc: 0.9458 | Val Acc: 0.4604
# Epoch 36 | Train Loss: 0.7966 | Train Acc: 0.9323 | Val Acc: 0.4260
# Epoch 37 | Train Loss: 0.7631 | Train Acc: 0.9545 | Val Acc: 0.4604
# Epoch 38 | Train Loss: 0.7363 | Train Acc: 0.9605 | Val Acc: 0.4425
# Epoch 39 | Train Loss: 0.7822 | Train Acc: 0.9534 | Val Acc: 0.4230
# Epoch 40 | Train Loss: 0.7429 | Train Acc: 0.9596 | Val Acc: 0.4230
# Epoch 41 | Train Loss: 0.7192 | Train Acc: 0.9647 | Val Acc: 0.4365
# Epoch 42 | Train Loss: 0.7094 | Train Acc: 0.9663 | Val Acc: 0.3991
# Epoch 43 | Train Loss: 0.7094 | Train Acc: 0.9702 | Val Acc: 0.4305
# Epoch 44 | Train Loss: 0.7615 | Train Acc: 0.9651 | Val Acc: 0.4380
# Epoch 45 | Train Loss: 0.6838 | Train Acc: 0.9747 | Val Acc: 0.4380
# Epoch 46 | Train Loss: 0.6576 | Train Acc: 0.9591 | Val Acc: 0.4096
# Epoch 47 | Train Loss: 0.9467 | Train Acc: 0.9503 | Val Acc: 0.4619
# Epoch 48 | Train Loss: 0.6867 | Train Acc: 0.9618 | Val Acc: 0.4679
# Epoch 49 | Train Loss: 0.6598 | Train Acc: 0.9789 | Val Acc: 0.4813
# Epoch 50 | Train Loss: 0.6211 | Train Acc: 0.9862 | Val Acc: 0.4425
# Epoch 51 | Train Loss: 0.6242 | Train Acc: 0.9860 | Val Acc: 0.4425
# Epoch 52 | Train Loss: 0.6001 | Train Acc: 0.9838 | Val Acc: 0.4410
# Epoch 53 | Train Loss: 0.5826 | Train Acc: 0.9842 | Val Acc: 0.4215
# Epoch 54 | Train Loss: 0.5654 | Train Acc: 0.9902 | Val Acc: 0.4439
# Epoch 55 | Train Loss: 0.5616 | Train Acc: 0.9887 | Val Acc: 0.4410
# Epoch 56 | Train Loss: 0.5657 | Train Acc: 0.9887 | Val Acc: 0.4365
# Epoch 57 | Train Loss: 0.5369 | Train Acc: 0.9925 | Val Acc: 0.4395
# Epoch 58 | Train Loss: 0.5514 | Train Acc: 0.9940 | Val Acc: 0.4230
# Epoch 59 | Train Loss: 0.5431 | Train Acc: 0.9933 | Val Acc: 0.4664
# Epoch 60 | Train Loss: 0.5259 | Train Acc: 0.9927 | Val Acc: 0.4395
# Epoch 61 | Train Loss: 0.5316 | Train Acc: 0.9947 | Val Acc: 0.4380
# Epoch 62 | Train Loss: 0.5132 | Train Acc: 0.9503 | Val Acc: 0.4529
# Epoch 63 | Train Loss: 0.7304 | Train Acc: 0.9734 | Val Acc: 0.4454
# Epoch 64 | Train Loss: 0.5525 | Train Acc: 0.9842 | Val Acc: 0.4305
# Early stopping triggered after 64 epochs. Best Val Acc: 0.4813
# Balanced Accuracy: 0.4233
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.49      0.40      0.44        87
#            1       0.24      0.15      0.19        72
#            2       0.38      0.38      0.38       103
#            3       0.55      0.72      0.62        98
#            4       0.42      0.58      0.49        67
#            5       0.49      0.34      0.40        80
#            6       0.34      0.45      0.38        87
#            7       0.49      0.36      0.42        75
#
#     accuracy                           0.43       669
#    macro avg       0.42      0.42      0.41       669
# weighted avg       0.43      0.43      0.42       669
# Final Validation Accuracy: 0.4305
#
# Running configuration 5/6
# Model: CNN, Batch Size: 100, LR: 0.0002, Conv: [(8, 10), (32, 10), (128, 10), (512, 10), (128, 10)], Layers: [64], Dropout: 0.85
# ____________________update_3___________________________
# Using device: cuda
# Model: CNN, Layers: [64], Dropout: 0.85, LR: 0.0002
# pushed 1:44ipup
# Epoch 1 | Train Loss: 2.0579 | Train Acc: 0.2556 | Val Acc: 0.2063
# Epoch 2 | Train Loss: 2.0113 | Train Acc: 0.2913 | Val Acc: 0.2257
# Epoch 3 | Train Loss: 1.9573 | Train Acc: 0.3139 | Val Acc: 0.2063
# Epoch 4 | Train Loss: 1.9105 | Train Acc: 0.3439 | Val Acc: 0.2451
# Epoch 5 | Train Loss: 1.8561 | Train Acc: 0.3965 | Val Acc: 0.2212
# Epoch 6 | Train Loss: 1.8408 | Train Acc: 0.4403 | Val Acc: 0.2616
# Epoch 7 | Train Loss: 1.8046 | Train Acc: 0.4887 | Val Acc: 0.2541
# Epoch 8 | Train Loss: 1.7523 | Train Acc: 0.5011 | Val Acc: 0.2840
# Epoch 9 | Train Loss: 1.7025 | Train Acc: 0.4887 | Val Acc: 0.3348
# Epoch 10 | Train Loss: 1.6583 | Train Acc: 0.5433 | Val Acc: 0.2661
# Epoch 11 | Train Loss: 1.6047 | Train Acc: 0.5935 | Val Acc: 0.3154
# Epoch 12 | Train Loss: 1.5327 | Train Acc: 0.5972 | Val Acc: 0.3662
# Epoch 13 | Train Loss: 1.5323 | Train Acc: 0.6323 | Val Acc: 0.3274
# Epoch 14 | Train Loss: 1.4736 | Train Acc: 0.6710 | Val Acc: 0.3318
# Epoch 15 | Train Loss: 1.4255 | Train Acc: 0.6978 | Val Acc: 0.3274
# Epoch 16 | Train Loss: 1.3960 | Train Acc: 0.7049 | Val Acc: 0.3363
# Epoch 17 | Train Loss: 1.3565 | Train Acc: 0.7425 | Val Acc: 0.3139
# Epoch 18 | Train Loss: 1.2717 | Train Acc: 0.7771 | Val Acc: 0.3483
# Epoch 19 | Train Loss: 1.2518 | Train Acc: 0.7700 | Val Acc: 0.3378
# Epoch 20 | Train Loss: 1.2201 | Train Acc: 0.7547 | Val Acc: 0.2960
# Epoch 21 | Train Loss: 1.2823 | Train Acc: 0.7762 | Val Acc: 0.3393
# Epoch 22 | Train Loss: 1.1831 | Train Acc: 0.8228 | Val Acc: 0.3303
# Epoch 23 | Train Loss: 1.2295 | Train Acc: 0.8457 | Val Acc: 0.3259
# Epoch 24 | Train Loss: 1.1170 | Train Acc: 0.8524 | Val Acc: 0.3483
# Epoch 25 | Train Loss: 1.1241 | Train Acc: 0.8641 | Val Acc: 0.3214
# Epoch 26 | Train Loss: 1.0370 | Train Acc: 0.8888 | Val Acc: 0.3064
# Epoch 27 | Train Loss: 1.0045 | Train Acc: 0.8686 | Val Acc: 0.3961
# Epoch 28 | Train Loss: 1.0359 | Train Acc: 0.9061 | Val Acc: 0.3363
# Epoch 29 | Train Loss: 0.9884 | Train Acc: 0.9067 | Val Acc: 0.3976
# Epoch 30 | Train Loss: 0.9398 | Train Acc: 0.8992 | Val Acc: 0.3857
# Epoch 31 | Train Loss: 0.9453 | Train Acc: 0.9145 | Val Acc: 0.3184
# Epoch 32 | Train Loss: 0.9239 | Train Acc: 0.9196 | Val Acc: 0.4215
# Epoch 33 | Train Loss: 0.8848 | Train Acc: 0.9074 | Val Acc: 0.3423
# Epoch 34 | Train Loss: 0.8648 | Train Acc: 0.9170 | Val Acc: 0.3602
# Epoch 35 | Train Loss: 0.8625 | Train Acc: 0.9421 | Val Acc: 0.3871
# Epoch 36 | Train Loss: 0.8748 | Train Acc: 0.9527 | Val Acc: 0.3931
# Epoch 37 | Train Loss: 0.8410 | Train Acc: 0.9281 | Val Acc: 0.3587
# Epoch 38 | Train Loss: 0.8614 | Train Acc: 0.9591 | Val Acc: 0.4320
# Epoch 39 | Train Loss: 0.7785 | Train Acc: 0.9627 | Val Acc: 0.4155
# Epoch 40 | Train Loss: 0.7788 | Train Acc: 0.9722 | Val Acc: 0.4245
# Epoch 41 | Train Loss: 0.7386 | Train Acc: 0.9629 | Val Acc: 0.4066
# Epoch 42 | Train Loss: 0.7346 | Train Acc: 0.9700 | Val Acc: 0.3857
# Epoch 43 | Train Loss: 0.7132 | Train Acc: 0.9714 | Val Acc: 0.4066
# Epoch 44 | Train Loss: 0.7158 | Train Acc: 0.9798 | Val Acc: 0.4006
# Epoch 45 | Train Loss: 0.6936 | Train Acc: 0.9780 | Val Acc: 0.4051
# Epoch 46 | Train Loss: 0.6722 | Train Acc: 0.9683 | Val Acc: 0.4111
# Epoch 47 | Train Loss: 0.6689 | Train Acc: 0.9720 | Val Acc: 0.3916
# Epoch 48 | Train Loss: 0.6982 | Train Acc: 0.9869 | Val Acc: 0.4021
# Epoch 49 | Train Loss: 0.6326 | Train Acc: 0.9736 | Val Acc: 0.3901
# Epoch 50 | Train Loss: 0.6336 | Train Acc: 0.9907 | Val Acc: 0.3976
# Epoch 51 | Train Loss: 0.6227 | Train Acc: 0.9825 | Val Acc: 0.4335
# Epoch 52 | Train Loss: 0.6115 | Train Acc: 0.9920 | Val Acc: 0.3812
# Epoch 53 | Train Loss: 0.6003 | Train Acc: 0.9911 | Val Acc: 0.4335
# Epoch 54 | Train Loss: 0.5708 | Train Acc: 0.9827 | Val Acc: 0.3946
# Epoch 55 | Train Loss: 0.5913 | Train Acc: 0.9944 | Val Acc: 0.4036
# Epoch 56 | Train Loss: 0.5584 | Train Acc: 0.9944 | Val Acc: 0.4126
# Epoch 57 | Train Loss: 0.5723 | Train Acc: 0.9905 | Val Acc: 0.4155
# Epoch 58 | Train Loss: 0.5365 | Train Acc: 0.9927 | Val Acc: 0.3812
# Epoch 59 | Train Loss: 0.5774 | Train Acc: 0.9931 | Val Acc: 0.4200
# Epoch 60 | Train Loss: 0.5350 | Train Acc: 0.9953 | Val Acc: 0.4170
# Epoch 61 | Train Loss: 0.5277 | Train Acc: 0.9953 | Val Acc: 0.3961
# Epoch 62 | Train Loss: 0.6039 | Train Acc: 0.9953 | Val Acc: 0.3991
# Epoch 63 | Train Loss: 0.5326 | Train Acc: 0.9907 | Val Acc: 0.3871
# Epoch 64 | Train Loss: 0.5267 | Train Acc: 0.9978 | Val Acc: 0.4036
# Epoch 65 | Train Loss: 0.5161 | Train Acc: 0.9964 | Val Acc: 0.4051
# Epoch 66 | Train Loss: 0.4978 | Train Acc: 0.9987 | Val Acc: 0.4006
# Early stopping triggered after 66 epochs. Best Val Acc: 0.4335
# Balanced Accuracy: 0.3968
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.49      0.52        87
#            1       0.29      0.50      0.37        72
#            2       0.29      0.36      0.32       103
#            3       0.51      0.57      0.54        98
#            4       0.48      0.36      0.41        67
#            5       0.50      0.34      0.40        80
#            6       0.36      0.29      0.32        87
#            7       0.36      0.27      0.31        75
#
#     accuracy                           0.40       669
#    macro avg       0.42      0.40      0.40       669
# weighted avg       0.42      0.40      0.40       669
# Final Validation Accuracy: 0.4006
#
# Running configuration 6/6
# Model: CNN, Batch Size: 100, LR: 0.0002, Conv: [(8, 10), (32, 10), (128, 10), (512, 10), (128, 10)], Layers: [64], Dropout: 0.85
# ____________________update_3___________________________
# Using device: cuda
# Model: CNN, Layers: [64], Dropout: 0.85, LR: 0.0002
# pushed 1:44ipup
# Epoch 1 | Train Loss: 2.0372 | Train Acc: 0.3068 | Val Acc: 0.1973
# Epoch 2 | Train Loss: 1.9740 | Train Acc: 0.3537 | Val Acc: 0.2676
# Epoch 3 | Train Loss: 1.9432 | Train Acc: 0.3934 | Val Acc: 0.2167
# Epoch 4 | Train Loss: 1.8984 | Train Acc: 0.4134 | Val Acc: 0.2900
# Epoch 5 | Train Loss: 1.8435 | Train Acc: 0.4256 | Val Acc: 0.2676
# Epoch 6 | Train Loss: 1.8019 | Train Acc: 0.4472 | Val Acc: 0.2167
# Epoch 7 | Train Loss: 1.7761 | Train Acc: 0.5102 | Val Acc: 0.2272
# Epoch 8 | Train Loss: 1.7259 | Train Acc: 0.5113 | Val Acc: 0.2735
# Epoch 9 | Train Loss: 1.6820 | Train Acc: 0.5218 | Val Acc: 0.2481
# Epoch 10 | Train Loss: 1.7105 | Train Acc: 0.4916 | Val Acc: 0.2317
# Epoch 11 | Train Loss: 1.6162 | Train Acc: 0.5775 | Val Acc: 0.3288
# Epoch 12 | Train Loss: 1.5503 | Train Acc: 0.6341 | Val Acc: 0.3423
# Epoch 13 | Train Loss: 1.5046 | Train Acc: 0.6465 | Val Acc: 0.3184
# Epoch 14 | Train Loss: 1.4600 | Train Acc: 0.6790 | Val Acc: 0.3662
# Epoch 15 | Train Loss: 1.4461 | Train Acc: 0.6807 | Val Acc: 0.3722
# Epoch 16 | Train Loss: 1.4293 | Train Acc: 0.7003 | Val Acc: 0.3453
# Epoch 17 | Train Loss: 1.3987 | Train Acc: 0.7371 | Val Acc: 0.3662
# Epoch 18 | Train Loss: 1.3166 | Train Acc: 0.7689 | Val Acc: 0.3288
# Epoch 19 | Train Loss: 1.2422 | Train Acc: 0.7624 | Val Acc: 0.3274
# Epoch 20 | Train Loss: 1.3236 | Train Acc: 0.7813 | Val Acc: 0.4021
# Epoch 21 | Train Loss: 1.2339 | Train Acc: 0.7964 | Val Acc: 0.3737
# Epoch 22 | Train Loss: 1.2006 | Train Acc: 0.8091 | Val Acc: 0.3976
# Epoch 23 | Train Loss: 1.1469 | Train Acc: 0.8097 | Val Acc: 0.3797
# Epoch 24 | Train Loss: 1.1488 | Train Acc: 0.8501 | Val Acc: 0.4111
# Epoch 25 | Train Loss: 1.0762 | Train Acc: 0.8111 | Val Acc: 0.3647
# Epoch 26 | Train Loss: 1.1464 | Train Acc: 0.8515 | Val Acc: 0.3857
# Epoch 27 | Train Loss: 1.0549 | Train Acc: 0.8834 | Val Acc: 0.4126
# Epoch 28 | Train Loss: 1.0298 | Train Acc: 0.8703 | Val Acc: 0.3991
# Epoch 29 | Train Loss: 0.9919 | Train Acc: 0.8703 | Val Acc: 0.3602
# Epoch 30 | Train Loss: 0.9895 | Train Acc: 0.9119 | Val Acc: 0.4141
# Epoch 31 | Train Loss: 0.9506 | Train Acc: 0.9016 | Val Acc: 0.4096
# Epoch 32 | Train Loss: 0.9096 | Train Acc: 0.9176 | Val Acc: 0.4454
# Epoch 33 | Train Loss: 0.8961 | Train Acc: 0.9194 | Val Acc: 0.4215
# Epoch 34 | Train Loss: 0.8726 | Train Acc: 0.9294 | Val Acc: 0.3916
# Epoch 35 | Train Loss: 0.8705 | Train Acc: 0.9245 | Val Acc: 0.4081
# Epoch 36 | Train Loss: 0.8385 | Train Acc: 0.9434 | Val Acc: 0.4380
# Epoch 37 | Train Loss: 0.8166 | Train Acc: 0.9445 | Val Acc: 0.4275
# Epoch 38 | Train Loss: 0.8115 | Train Acc: 0.9434 | Val Acc: 0.4215
# Epoch 39 | Train Loss: 0.7860 | Train Acc: 0.9443 | Val Acc: 0.3946
# Epoch 40 | Train Loss: 0.7620 | Train Acc: 0.9474 | Val Acc: 0.4260
# Epoch 41 | Train Loss: 0.7787 | Train Acc: 0.9321 | Val Acc: 0.4439
# Epoch 42 | Train Loss: 0.8630 | Train Acc: 0.9538 | Val Acc: 0.4365
# Epoch 43 | Train Loss: 0.7528 | Train Acc: 0.9667 | Val Acc: 0.4813
# Epoch 44 | Train Loss: 0.7217 | Train Acc: 0.9729 | Val Acc: 0.4335
# Epoch 45 | Train Loss: 0.7010 | Train Acc: 0.9540 | Val Acc: 0.4350
# Epoch 46 | Train Loss: 0.7151 | Train Acc: 0.9181 | Val Acc: 0.3438
# Epoch 47 | Train Loss: 0.8714 | Train Acc: 0.9656 | Val Acc: 0.4335
# Epoch 48 | Train Loss: 0.7195 | Train Acc: 0.9776 | Val Acc: 0.4469
# Epoch 49 | Train Loss: 0.6826 | Train Acc: 0.9776 | Val Acc: 0.4305
# Epoch 50 | Train Loss: 0.6736 | Train Acc: 0.9765 | Val Acc: 0.4634
# Epoch 51 | Train Loss: 0.6712 | Train Acc: 0.9769 | Val Acc: 0.4096
# Epoch 52 | Train Loss: 0.6537 | Train Acc: 0.9740 | Val Acc: 0.4021
# Epoch 53 | Train Loss: 0.6378 | Train Acc: 0.9816 | Val Acc: 0.4260
# Epoch 54 | Train Loss: 0.6150 | Train Acc: 0.9902 | Val Acc: 0.4245
# Epoch 55 | Train Loss: 0.6026 | Train Acc: 0.9880 | Val Acc: 0.4395
# Epoch 56 | Train Loss: 0.6361 | Train Acc: 0.9845 | Val Acc: 0.4350
# Epoch 57 | Train Loss: 0.6391 | Train Acc: 0.9849 | Val Acc: 0.4454
# Epoch 58 | Train Loss: 0.5961 | Train Acc: 0.9842 | Val Acc: 0.4335
# Early stopping triggered after 58 epochs. Best Val Acc: 0.4813
# Balanced Accuracy: 0.4287
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.64      0.49      0.56        87
#            1       0.51      0.36      0.42        72
#            2       0.28      0.27      0.27       103
#            3       0.53      0.79      0.64        98
#            4       0.51      0.39      0.44        67
#            5       0.54      0.19      0.28        80
#            6       0.31      0.37      0.34        87
#            7       0.35      0.57      0.43        75
#
#     accuracy                           0.43       669
#    macro avg       0.46      0.43      0.42       669
# weighted avg       0.45      0.43      0.42       669
# Final Validation Accuracy: 0.4335
